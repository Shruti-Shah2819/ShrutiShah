# %%
# This is a Python program which demonstrate the use of 1.functions,
#2.python loops like while loop, for loop,
#3.pyton statements like if-elif-else statement,
#4.input function,
#5. break keyword


def area():
    '''
    This function takes input from user and claculates the area.
    input: any two numbers integer,float.
    output: generates out area.
    '''
    
    print("\n\n Enter the Parameters of Rectangle.\n\n")
   
    length = input("\n Enter Length.")
    breadth = input("\n Enter Breadth.")
    
    result = int(length)* int(breadth)
    
    print("\n\nThe Area of rectangle with Length {l} and Breadth {b} is: \t {r}".format(l=length,b=breadth,r=result) )
    



name=input("ENTER YOUR NAME")
print("\n\nHEY {n} THIS IS MY SECOND PYTHON PROGRAM..  :)\n\n".format(n=name))
print("\nLETS PLAY THE GAME\n")
j=0
while j!=4:
    
        print("\n WHAT YOU WANT TO DO \n")
        print("\n1. Print 'EVEN' numbers ")
        print("\n2. Print 'ODD' numbers ")
        print("\n3. Print 'Area' of Rectangle ")
        print("\n4. I Want To Exit Game")
        n = int(input(" ENTER YOUR CHOICE "))

        if n == 1:

            print("\n Here are your 'EVEN' numbers")
            for i in range(0,11,2):
                print(i)

        elif n == 2:
            print("\n Here are your 'ODD' numbers")
            for i in range(1,11,2):

                print(i)

        elif n == 3:
            area()
            
        else:
            print("GOOD BYE {n} , YOU PLAYED WELL :)".format(n=name))
            break
j = n+1
# Out:
# ENTER YOUR NAMEShruti Shah
#
#
# HEY Shruti Shah THIS IS MY SECOND PYTHON PROGRAM..  :)
#
#
#
# LETS PLAY THE GAME
#
#
#  WHAT YOU WANT TO DO
#
#
# 1. Print 'EVEN' numbers
#
# 2. Print 'ODD' numbers
#
# 3. Print 'Area' of Rectangle
#
# 4. I Want To Exit Game
#  ENTER YOUR CHOICE 1
#
#  Here are your 'EVEN' numbers
# 0
# 2
# 4
# 6
# 8
# 10
#
#  WHAT YOU WANT TO DO
#
#
# 1. Print 'EVEN' numbers
#
# 2. Print 'ODD' numbers
#
# 3. Print 'Area' of Rectangle
#
# 4. I Want To Exit Game
#  ENTER YOUR CHOICE 2
#
#  Here are your 'ODD' numbers
# 1
# 3
# 5
# 7
# 9
#
#  WHAT YOU WANT TO DO
#
#
# 1. Print 'EVEN' numbers
#
# 2. Print 'ODD' numbers
#
# 3. Print 'Area' of Rectangle
#
# 4. I Want To Exit Game
#  ENTER YOUR CHOICE 3
#
#
#  Enter the Parameters of Rectangle.
#
#
#
#  Enter Length.12
#
#  Enter Breadth.4
#
#
# The Area of rectangle with Length 12 and Breadth 4 is: 	 48
#
#  WHAT YOU WANT TO DO
#
#
# 1. Print 'EVEN' numbers
#
# 2. Print 'ODD' numbers
#
# 3. Print 'Area' of Rectangle
#
# ...
